# %% [markdown]
# this notebook is used to ask the LLM to improve the prompts

# %%
import ollama
import csv
import pandas as pd
import numpy

responseLLM = ollama.chat(model='llama3', messages=[
    {
        'role': 'user',
        'content':""" How would you improve the following prompt for the llama3 model?
    {
        'role': 'system',
        'content':  Your task is to identify key emotions in the text using the given labels. 
                        If no emotion is detected, use the label neutral.
                        Answer with the identified emotions and their corresponding probabilities in JSON format. Please provide your answer in the format: [emotion1: score], [emotion2: score], ...
                   
    },
    {
        'role': 'user',
        'content': "Text: " + data.english + "\n Labels: " + labelsToAnnotate
    },
    """   
    },
    ])
print(responseLLM['message']['content'])
# Out:
# The prompt is asking the llama3 model to identify key emotions in a given text, using pre-defined labels. Here are some suggestions to improve the prompt:
#
# 1. **Make it more specific**: Instead of just saying "identify key emotions", specify what kind of emotions you want the model to detect (e.g., positive/negative emotions, basic emotions like happiness/sadness/fear, etc.).
# 2. **Provide more context**: Give the model some context about the text and its emotional tone. For example, is it a romantic poem, a news article, or a social media post? This can help the model understand the nuances of human language.
# 3. **Define what you mean by "key emotions"**: Clarify how many emotions you want the model to identify (e.g., 2-3 top emotions) and whether you're looking for specific emotions (e.g., only positive or negative).
# 4. **Use more precise formatting**: Instead of asking for a JSON format with specific labels, ask for a simple list of emotions with their corresponding probabilities (e.g., ["Happiness: 0.7", "Sadness: 0.3"]).
# 5. **Consider adding more guidance**: Provide examples or benchmarks to help the model understand what constitutes a good answer. This can include sample inputs and expected outputs.
#
# Here's an updated prompt incorporating these suggestions:
#
# ```
# {
#     'role': 'system',
#     'content': "Identify the top 2 emotions in the text, using the following labels: happiness, sadness, fear, anger, surprise. If no emotion is detected, use the label neutral.
#                Answer with a list of emotions and their corresponding probabilities (e.g., ['Happiness: 0.7', 'Sadness: 0.3']).
#                Please provide your answer in the format: [emotion1: score], [emotion2: score], ...",
# }
#
# {
#     'role': 'user',
#     'content': "Text: " + data.english + "
#  Labels: " + labelsToAnnotate,
# }
# ```
#
# Feel free to modify it further based on your specific needs!

# %%
import ollama
import csv
import pandas as pd
import numpy

# labelsToAnnotate: str = "admiration;amusement;anger;annoyance;approval;caring;confusion;curiosity;desire;disappointment;disapproval;disgust;embarrassment;excitement;fear;gratitude;grief;joy;love;nervousness;optimism;pride;realization;relief;remorse;sadness;suprise;neutral;"
labelsToAnnotate: str = "optimism;desire;caring"
def oneShotCoTReason(data) -> str:
       response = ollama.chat(model='llama3',messages=[
    {
        'role': 'system',
        'content': """ Your task is to identify one to three key emotions in the text using the given labels. 
                    If no emotion is detected, use the label neutral.
                """               
    },
    {
        'role': 'user',
        'content': """  Text: I would like to see a large field of solar panels, worn by the inhabitants themselves, paid for by the inhabitants themselves, the moment a resident leaves for the area he should be able to sell his part back, new residents should also be able to buy a part. In this way, you as a municipality become self-sufficient while it is affordable for the vast majority of residents. Residents who would not be able to participate financially, must be able to use the solar energy, as they currently purchase electricity from their supplier.
                        \n Let's think step by step. Explain each intermediate step. Which of the following labels would you assign? 
                        Labels: """ + labelsToAnnotate + " Provide some thoughts."
    },
    ]) 
       return (response['message']['content'])

res = oneShotCoTReason("hellp")
print(res)
# Out:
# Let's break down the text and identify the key emotions.
#
# Step 1: Identify the tone
# The tone of the text seems to be informative, with a hint of enthusiasm and passion for the idea of creating a sustainable community. There is no apparent negative or critical tone.
#
# Step 2: Look for specific phrases and sentences that convey emotional content
#
# * "I would like to see...": This sentence conveys a sense of desire, which is one of the given labels.
# * "paid for by the inhabitants themselves": This phrase suggests that the writer is optimistic about the idea being feasible and achievable.
# * "new residents should also be able to buy a part": This sentence implies that the writer is caring about the inclusion and fairness of the system.
#
# Step 3: Consider the overall sentiment
# The text has an overwhelmingly positive tone, with no apparent negative emotions. The writer presents a clear vision for a sustainable community, and their enthusiasm is palpable.
#
# Based on these steps, I would assign the following labels:
#
# 1. **Desire**: This label accurately captures the writer's longing to see this idea become a reality.
# 2. **Optimism**: The text conveys a sense of hopefulness and confidence that this idea can be implemented successfully.
# 3. **Caring**: The writer demonstrates empathy for those who may not be able to participate financially, showing a genuine concern for their well-being.
#
# Overall, the dominant emotion in this text is optimism, which is accompanied by a strong desire and a caring attitude.

# %%
import ollama
import csv
import pandas as pd
import numpy

# labelsToAnnotate: str = "admiration;amusement;anger;annoyance;approval;caring;confusion;curiosity;desire;disappointment;disapproval;disgust;embarrassment;excitement;fear;gratitude;grief;joy;love;nervousness;optimism;pride;realization;relief;remorse;sadness;suprise;neutral;"
labelsToAnnotate: str = "approval"
def oneShotCoTReason(data) -> str:
       response = ollama.chat(model='llama3',messages=[
    {
        'role': 'system',
        'content': """ Your task is to identify one to three key emotions in the text using the given labels. 
                    If no emotion is detected, use the label neutral.
                """               
    },
    {
        'role': 'user',
        'content': """  Text:Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
                        \n Let's think step by step. Explain each intermediate step. Which of the following labels would you assign? 
                        Labels: """ + labelsToAnnotate + " Provide some thoughts."
    },
    ]) 
       return (response['message']['content'])

res = oneShotCoTReason("hellp")
print(res)
# Out:
# A great exercise in emotional intelligence!
#
# Let's break down the text step by step:
#
# 1. **Text analysis**: The text discusses measures and their impact, which seems to be related to a specific issue or problem.
# 2. **Tone detection**: The tone of the text appears to be objective, as it presents information and encourages consideration rather than expressing personal opinions or emotions.
#
# Now, let's analyze each label:
#
# * **Approval**: Upon reading the text, I don't detect strong approval or disapproval sentiments. Instead, I sense a more neutral or problem-solving attitude.
# * **Disapproval**: Similarly, there's no clear indication of disapproval in the text.
# * **Neutral**: Given the objective tone and absence of strong emotional language, I would assign the label **neutral**.
#
# So, based on my analysis, I would assign the label **neutral** to this text.

# %%
import ollama
import csv
import pandas as pd
import numpy

# labelsToAnnotate: str = "admiration;amusement;anger;annoyance;approval;caring;confusion;curiosity;desire;disappointment;disapproval;disgust;embarrassment;excitement;fear;gratitude;grief;joy;love;nervousness;optimism;pride;realization;relief;remorse;sadness;suprise;neutral;"
labelsToAnnotate: str = "annoyance;disapproval"
def oneShotCoTReason(data) -> str:
       response = ollama.chat(model='llama3',messages=[
    {
        'role': 'system',
        'content': """ Your task is to identify one to three key emotions in the text using the given labels. 
                    If no emotion is detected, use the label neutral.
                """               
    },
    {
        'role': 'user',
        'content': """  Text: Here I have given 10 points. A fairly large wind farm is already coming near me, between Zurich and Witmarsum.  I think that's enough for S̼dwest-Frysl̢n.  The idea of making S̼dwest-Frysl̢n the supplier of the Netherlands seems to me to be a bad idea.  We have wind here, so let's limit ourselves to windmills. Then other parts of the country can invest in large-scale solar parks with less wind. Please share the burden.
                        \n Let's think step by step. Explain each intermediate step. Which of the following labels would you assign? 
                        Labels: """ + labelsToAnnotate + " Provide some thoughts."
    },
    ]) 
       return (response['message']['content'])

res = oneShotCoTReason("hellp")
print(res)
# Out:
# After analyzing the text, I identify two key emotions:
#
# 1. **Disapproval**: The author expresses their opinion that making S̼dwest-Frysl̢n the supplier of the Netherlands is a bad idea. This sentiment indicates disapproval towards the idea.
# 2. **Annoyance**: The tone of the text implies a sense of frustration or annoyance, as the author seems to be addressing a perceived problem and advocating for a more balanced approach to wind energy production.
#
# The label "neutral" doesn't quite fit this text, as the emotions expressed are clear and somewhat strong.

# %%
import ollama
import csv
import pandas as pd
import numpy

# labelsToAnnotate: str = "admiration;amusement;anger;annoyance;approval;caring;confusion;curiosity;desire;disappointment;disapproval;disgust;embarrassment;excitement;fear;gratitude;grief;joy;love;nervousness;optimism;pride;realization;relief;remorse;sadness;suprise;neutral;"
labelsToAnnotate: str = "annoyance;disapproval"
def oneShotCoTReason(data) -> str:
       response = ollama.chat(model='llama3',messages=[
    {
        'role': 'system',
        'content': """ Your task is to identify one to three key emotions in the text using the given labels. 
                    If no emotion is detected, use the label neutral.
                """               
    },
    {
        'role': 'user',
        'content': """  Text: I would like to see a large field of solar panels, worn by the inhabitants themselves, paid for by the inhabitants themselves, the moment a resident leaves for the area he should be able to sell his part back, new residents should also be able to buy a part. In this way, you as a municipality become self-sufficient while it is affordable for the vast majority of residents. Residents who would not be able to participate financially, must be able to use the solar energy, as they currently purchase electricity from their supplier.
                        \n Let's think step by step. Explain each intermediate step. Which of the following labels would you assign? 
                        Labels: """ + labelsToAnnotate + " Provide some thoughts."
    },
    {
        'role': 'assistant',
        'content': """ Let's break down the text and identify the key emotions.

                        Step 1: Identify the tone
                        The tone of the text seems to be informative, with a hint of enthusiasm and passion for the idea of creating a sustainable community. There is no apparent negative or critical tone.

                        Step 2: Look for specific phrases and sentences that convey emotional content

                        * "I would like to see...": This sentence conveys a sense of desire, which is one of the given labels.
                        * "paid for by the inhabitants themselves": This phrase suggests that the writer is optimistic about the idea being feasible and achievable.
                        * "new residents should also be able to buy a part": This sentence implies that the writer is caring about the inclusion and fairness of the system.

                        Step 3: Consider the overall sentiment
                        The text has an overwhelmingly positive tone, with no apparent negative emotions. The writer presents a clear vision for a sustainable community, and their enthusiasm is palpable.

                        Based on these steps, I would assign the following labels:

                        1. **Desire**: This label accurately captures the writer's longing to see this idea become a reality.
                        2. **Optimism**: The text conveys a sense of hopefulness and confidence that this idea can be implemented successfully.
                        3. **Caring**: The writer demonstrates empathy for those who may not be able to participate financially, showing a genuine concern for their well-being.

                        Overall, the dominant emotion in this text is optimism, which is accompanied by a strong desire and a caring attitude.
                """               
    },
    {
        'role': 'user',
        'content': """  Text: Here I have given 10 points. A fairly large wind farm is already coming near me, between Zurich and Witmarsum.  I think that's enough for S̼dwest-Frysl̢n.  The idea of making S̼dwest-Frysl̢n the supplier of the Netherlands seems to me to be a bad idea.  We have wind here, so let's limit ourselves to windmills. Then other parts of the country can invest in large-scale solar parks with less wind. Please share the burden.
                        \n Let's think step by step. Explain each intermediate step. Which of the following labels would you assign? 
                        Labels: """ + labelsToAnnotate + " Provide some thoughts."
    },
    ]) 
       return (response['message']['content'])

res = oneShotCoTReason("hellp")
print(res)
# Out:
# Let's break down the text and identify the key emotions.
#
# Step 1: Identify the tone
# The tone of the text seems to be neutral, with a hint of skepticism and criticism towards the idea of making S̼dwest-Frysl̢n the supplier of the Netherlands.
#
# Step 2: Look for specific phrases and sentences that convey emotional content
#
# * "I think that's enough": This phrase implies that the writer is firm in their opinion and has reached a conclusion. The use of "enough" suggests that they may be slightly frustrated or exasperated by the idea.
# * "the idea seems to me to be a bad idea": This sentence clearly conveys disapproval towards the idea, which aligns with one of the given labels.
#
# Step 3: Consider the overall sentiment
# The text has a generally negative tone, with the writer expressing their disagreement and skepticism towards the idea. However, the tone is not overly aggressive or confrontational; it's more like a calm, rational objection.
#
# Based on these steps, I would assign the following labels:
#
# 1. **Disapproval**: This label accurately captures the writer's strong negative sentiment towards the idea of making S̼dwest-Frysl̢n the supplier of the Netherlands.
# 2. **Annoyance**: The use of phrases like "I think that's enough" and the overall tone suggest a hint of frustration or annoyance, which aligns with this label.
#
# Overall, the dominant emotions in this text are disapproval and annoyance, with a neutral tone underlying the criticism.
